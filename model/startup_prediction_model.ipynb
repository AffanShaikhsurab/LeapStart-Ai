# %%
# pip install pandas numpy scikit-learn tensorflow joblib

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, log_loss
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Conv1D, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import joblib
import os
from tensorflow.keras import regularizers

# Load dataset
df = pd.read_csv('./dataset_transformed.csv')
epoch = 1000
l2_penalty = 0.001

# Drop rows with missing values in critical columns
df.dropna(subset=['status', 'funding_total_usd', 'country_code'], inplace=True)

# Encode categorical columns
label_encoders = {}
for column in ['category_list', 'country_code', 'state_code', 'region', 'city', 'first_funding_at', 'last_funding_at', 'founded_at']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le

# Convert 'status' to binary classification (1 for operating, 0 for closed)
df['status'] = df['status'].apply(lambda x: 0 if x == 'closed' else 1)

# Handle 'funding_total_usd' column (convert '-' to 0 and convert to float)
df['funding_total_usd'] = df['funding_total_usd'].replace('-', 0).astype(float)

# Features and target
X = df.drop(columns=['status'])
y = df['status']

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

print("The transformed input-values are:\n\n", X)

def build_model(input_dim, focus='general', model_type='mlp'):
    model = Sequential()

    if model_type == 'mlp':
        if focus == 'financial':
            model.add(Dense(30, activation='relu', input_dim=input_dim, kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
            model.add(Dense(15, activation='relu', kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
        elif focus == 'market':
            model.add(Dense(20, activation='relu', input_dim=input_dim, kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
            model.add(Dense(15, activation='relu', kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
        elif focus == 'team':
            model.add(Dense(14, activation='relu', input_dim=input_dim, kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
            model.add(Dense(9, activation='relu', kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
        elif focus == 'innovation':
            model.add(Dense(18, activation='relu', input_dim=input_dim, kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
            model.add(Dense(11, activation='relu', kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
        else:
            model.add(Dense(17, activation='relu', input_dim=input_dim, kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
            model.add(Dense(10, activation='relu', kernel_regularizer=regularizers.l2(l2_penalty)))
            model.add(Dropout(0.5))
        model.add(Dense(1, activation='sigmoid'))

    elif model_type == 'lstm':
        model.add(tf.keras.layers.Reshape((input_dim, 1), input_shape=(input_dim,)))
        model.add(LSTM(15, activation='relu', input_shape=(input_dim, 1)))
        model.add(Dropout(0.5))
        model.add(Dense(1, activation='sigmoid'))

    elif model_type == 'cnn':
        model.add(tf.keras.layers.Reshape((input_dim, 1), input_shape=(input_dim,)))
        model.add(Conv1D(13, 2, activation='relu', input_shape=(input_dim, 1), kernel_regularizer=regularizers.l2(l2_penalty)))
        model.add(Dropout(0.5))
        model.add(Flatten())
        model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

def build_random_forest():
    return RandomForestClassifier(n_estimators=20, random_state=42)

# Define different market niches (e.g., by category_list)
market_niches = df['category_list'].unique()

# Prepare a dictionary to store models for each market niche
niche_models = {}
for niche in market_niches:
    niche_indices = df['category_list'] == niche
    X_niche = X[niche_indices]
    y_niche = y[niche_indices]

    # Check if there are enough samples to split
    if len(X_niche) < 10:
        print(f"Skipping niche {niche} due to insufficient data.")
        continue

    # Split the data for training and testing
    X_train, X_test, y_train, y_test = train_test_split(X_niche, y_niche, test_size=0.3, random_state=42)

    # Initialize models for each focus and type
    niche_models[niche] = {
        'mlp_financial': build_model(X_train.shape[1], focus='financial', model_type='mlp'),
        'mlp_market': build_model(X_train.shape[1], focus='market', model_type='mlp'),
        'lstm': build_model(X_train.shape[1], model_type='lstm'),
        'cnn': build_model(X_train.shape[1], model_type='cnn'),
        'random_forest': build_random_forest()
    }

    # Train each model
    for model_name, model in niche_models[niche].items():
        print(f"Training model {model_name} for niche {niche}...")
        if model_name == 'random_forest':
            model.fit(X_train, y_train)
        else:
            checkpoint_path = f"model_checkpoints/{niche}_{model_name}_checkpoint.weights.h5"
            os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
            checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True)
            early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
            history = model.fit(X_train, y_train, epochs=epoch, batch_size=30, validation_split=0.2, verbose=1, callbacks=[checkpoint, early_stopping])
            print(f"Model {model_name} training complete for niche {niche}.")
            print(f"  Final training loss: {history.history['loss'][-1]}")
            print(f"  Final validation loss: {history.history['val_loss'][-1]}")
            print(f"  Final training accuracy: {history.history['accuracy'][-1]}")
            print(f"  Final validation accuracy: {history.history['val_accuracy'][-1]}")

# Evaluate models on the test set for each niche
niche_performance = {}

for niche, models in niche_models.items():
    niche_indices = df['category_list'] == niche
    X_niche = X[niche_indices]
    y_niche = y[niche_indices]

    if len(X_niche) < 10:
        continue

    X_train, X_test, y_train, y_test = train_test_split(X_niche, y_niche, test_size=0.3, random_state=42)

    niche_performance[niche] = {}

    for model_name, model in models.items():
        if model_name == 'random_forest':
            y_pred = model.predict_proba(X_test)[:, 1]
            eval_result = [log_loss(y_test, y_pred), accuracy_score(y_test, model.predict(X_test))]
        else:
            eval_result = model.evaluate(X_test, y_test, verbose=0)

        niche_performance[niche][model_name] = eval_result

# Print performance for each niche
for niche, performance in niche_performance.items():
    print(f"Performance for niche {niche}:")
    for model_name, result in performance.items():
        print(f"  {model_name}: Loss = {result[0]}, Accuracy = {result[1]}")

# Compare specialized models with the baseline for each niche
best_models = {}

for niche, performance in niche_performance.items():
    best_model_name = min(performance, key=lambda k: performance[k][0])  # assuming lower loss is better
    best_models[niche] = best_model_name

    print(f"Best performing model for niche {niche}: {best_model_name} with performance: {performance[best_model_name]}")

# Save the best models
for niche, best_model_name in best_models.items():
    best_model = niche_models[niche][best_model_name]
    if best_model_name == 'random_forest':
        joblib.dump(best_model, f'best_model_{niche}.pkl')
    else:
        best_model.save(f'best_model_{niche}.h5')
# Out:
# The transformed input-values are:
#
#  [[ 0.08915953 -0.18514222 -1.91104785 ... -0.69005976 -1.03768249
#   -1.63025802]
#  [ 1.41067941 -0.20808567  0.63247597 ...  0.05830927  1.17438633
#    0.75892076]
#  [-0.57160041 -0.19933445 -2.02163584 ... -1.30314011 -0.5881773
#   -1.07881043]
#  ...
#  [-0.57160041 -0.17726573 -2.39026248 ... -0.69005976  0.60707189
#    0.11642018]
#  [-1.23236035 -0.19523734 -1.35810788 ...  1.7348614   1.04971441
#    1.02310263]
#  [-1.56274032 -0.20677441 -1.24751989 ...  1.03101776  0.14841646
#    0.5870743 ]]
# Training model mlp_financial for niche 5...
# Epoch 1/1000
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\keras\src\layers\reshaping\reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6516 - loss: 0.6898 - val_accuracy: 0.8498 - val_loss: 0.5970
# Epoch 2/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7710 - loss: 0.6158 - val_accuracy: 0.8541 - val_loss: 0.5312
# Epoch 3/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7965 - loss: 0.5630 - val_accuracy: 0.8541 - val_loss: 0.4878
# Epoch 4/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8156 - loss: 0.5292 - val_accuracy: 0.8541 - val_loss: 0.4538
# Epoch 5/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8148 - loss: 0.5053 - val_accuracy: 0.8541 - val_loss: 0.4328
# Epoch 6/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8180 - loss: 0.5198 - val_accuracy: 0.8541 - val_loss: 0.4199
# Epoch 7/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - loss: 0.4837 - val_accuracy: 0.8541 - val_loss: 0.4112
# Epoch 8/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8255 - loss: 0.4832 - val_accuracy: 0.8541 - val_loss: 0.4047
# Epoch 9/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8216 - loss: 0.4587 - val_accuracy: 0.8541 - val_loss: 0.4006
# Epoch 10/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8122 - loss: 0.4809 - val_accuracy: 0.8541 - val_loss: 0.3977
# Epoch 11/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8277 - loss: 0.4477 - val_accuracy: 0.8541 - val_loss: 0.3944
# Epoch 12/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.4698 - val_accuracy: 0.8541 - val_loss: 0.3935
# Epoch 13/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8452 - loss: 0.4515 - val_accuracy: 0.8541 - val_loss: 0.3911
# Epoch 14/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8189 - loss: 0.4847 - val_accuracy: 0.8541 - val_loss: 0.3897
# Epoch 15/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8236 - loss: 0.4937 - val_accuracy: 0.8541 - val_loss: 0.3902
# Epoch 16/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8120 - loss: 0.4802 - val_accuracy: 0.8541 - val_loss: 0.3888
# Epoch 17/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8292 - loss: 0.4186 - val_accuracy: 0.8541 - val_loss: 0.3863
# Epoch 18/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8051 - loss: 0.4773 - val_accuracy: 0.8541 - val_loss: 0.3852
# Epoch 19/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8222 - loss: 0.4694 - val_accuracy: 0.8541 - val_loss: 0.3842
# Epoch 20/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8175 - loss: 0.4632 - val_accuracy: 0.8541 - val_loss: 0.3834
# Epoch 21/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8414 - loss: 0.4136 - val_accuracy: 0.8541 - val_loss: 0.3829
# Epoch 22/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8172 - loss: 0.4354 - val_accuracy: 0.8541 - val_loss: 0.3823
# Epoch 23/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8116 - loss: 0.4666 - val_accuracy: 0.8541 - val_loss: 0.3815
# Epoch 24/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8083 - loss: 0.4387 - val_accuracy: 0.8541 - val_loss: 0.3810
# Epoch 25/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8399 - loss: 0.4457 - val_accuracy: 0.8541 - val_loss: 0.3799
# Epoch 26/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8173 - loss: 0.4215 - val_accuracy: 0.8541 - val_loss: 0.3794
# Epoch 27/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8296 - loss: 0.4240 - val_accuracy: 0.8541 - val_loss: 0.3795
# Epoch 28/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.4144 - val_accuracy: 0.8541 - val_loss: 0.3791
# Epoch 29/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8161 - loss: 0.4425 - val_accuracy: 0.8541 - val_loss: 0.3791
# Epoch 30/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8178 - loss: 0.4336 - val_accuracy: 0.8541 - val_loss: 0.3795
# Epoch 31/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8410 - loss: 0.4026 - val_accuracy: 0.8541 - val_loss: 0.3790
# Epoch 32/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8295 - loss: 0.4265 - val_accuracy: 0.8541 - val_loss: 0.3784
# Epoch 33/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.4334 - val_accuracy: 0.8541 - val_loss: 0.3783
# Epoch 34/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8201 - loss: 0.4169 - val_accuracy: 0.8541 - val_loss: 0.3776
# Epoch 35/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8338 - loss: 0.4323 - val_accuracy: 0.8541 - val_loss: 0.3773
# Epoch 36/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8340 - loss: 0.4116 - val_accuracy: 0.8541 - val_loss: 0.3774
# Epoch 37/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4515 - val_accuracy: 0.8541 - val_loss: 0.3775
# Epoch 38/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8391 - loss: 0.4164 - val_accuracy: 0.8541 - val_loss: 0.3776
# Epoch 39/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8138 - loss: 0.4487 - val_accuracy: 0.8541 - val_loss: 0.3776
# Epoch 40/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8352 - loss: 0.4058 - val_accuracy: 0.8541 - val_loss: 0.3770
# Epoch 41/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8284 - loss: 0.4225 - val_accuracy: 0.8541 - val_loss: 0.3770
# Epoch 42/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8191 - loss: 0.4530 - val_accuracy: 0.8541 - val_loss: 0.3764
# Epoch 43/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8254 - loss: 0
1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.3771 - val_accuracy: 0.8541 - val_loss: 0.3716
# Epoch 80/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8308 - loss: 0.4109 - val_accuracy: 0.8541 - val_loss: 0.3719
# Epoch 81/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8302 - loss: 0.4137 - val_accuracy: 0.8541 - val_loss: 0.3717
# Epoch 82/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8294 - loss: 0.4099 - val_accuracy: 0.8541 - val_loss: 0.3717
# Epoch 83/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.3895 - val_accuracy: 0.8541 - val_loss: 0.3718
# Epoch 84/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.4310 - val_accuracy: 0.8541 - val_loss: 0.3712
# Epoch 85/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8271 - loss: 0.4058 - val_accuracy: 0.8541 - val_loss: 0.3700
# Epoch 86/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8314 - loss: 0.4158 - val_accuracy: 0.8541 - val_loss: 0.3689
# Epoch 87/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8189 - loss: 0.4104 - val_accuracy: 0.8541 - val_loss: 0.3683
# Epoch 88/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8133 - loss: 0.4325 - val_accuracy: 0.8541 - val_loss: 0.3684
# Epoch 89/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8060 - loss: 0.4399 - val_accuracy: 0.8541 - val_loss: 0.3688
# Epoch 90/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8274 - loss: 0.3807 - val_accuracy: 0.8541 - val_loss: 0.3696
# Epoch 91/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8161 - loss: 0.4243 - val_accuracy: 0.8541 - val_loss: 0.3694
# Epoch 92/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8022 - loss: 0.4141 - val_accuracy: 0.8541 - val_loss: 0.3697
# Epoch 93/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8206 - loss: 0.4073 - val_accuracy: 0.8541 - val_loss: 0.3689
# Epoch 94/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8120 - loss: 0.4386 - val_accuracy: 0.8541 - val_loss: 0.3674
# Epoch 95/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8232 - loss: 0.4120 - val_accuracy: 0.8541 - val_loss: 0.3671
# Epoch 96/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8362 - loss: 0.4111 - val_accuracy: 0.8541 - val_loss: 0.3676
# Epoch 97/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8275 - loss: 0.4405 - val_accuracy: 0.8541 - val_loss: 0.3682
# Epoch 98/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8180 - loss: 0.4178 - val_accuracy: 0.8541 - val_loss: 0.3689
# Epoch 99/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8409 - loss: 0.3742 - val_accuracy: 0.8541 - val_loss: 0.3685
# Epoch 100/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8318 - loss: 0.4099 - val_accuracy: 0.8541 - val_loss: 0.3685
# Epoch 101/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8205 - loss: 0.4181 - val_accuracy: 0.8541 - val_loss: 0.3684
# Epoch 102/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8223 - loss: 0.4103 - val_accuracy: 0.8541 - val_loss: 0.3685
# Epoch 103/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8178 - loss: 0.4148 - val_accuracy: 0.8541 - val_loss: 0.3684
# Epoch 104/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8302 - loss: 0.3967 - val_accuracy: 0.8541 - val_loss: 0.3683
# Epoch 105/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8327 - loss: 0.3769 - val_accuracy: 0.8541 - val_loss: 0.3684
# Model mlp_market training complete for niche 5.
#   Final training loss: 0.4051397740840912
#   Final validation loss: 0.36840611696243286
#   Final training accuracy: 0.8225806355476379
#   Final validation accuracy: 0.8540772795677185
# Training model lstm for niche 5...
# Epoch 1/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6463 - loss: 0.6712 - val_accuracy: 0.8541 - val_loss: 0.6216
# Epoch 2/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8019 - loss: 0.6078 - val_accuracy: 0.8541 - val_loss: 0.5323
# Epoch 3/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8206 - loss: 0.5338 - val_accuracy: 0.8541 - val_loss: 0.4533
# Epoch 4/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8205 - loss: 0.5030 - val_accuracy: 0.8541 - val_loss: 0.4278
# Epoch 5/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8209 - loss: 0.4993 - val_accuracy: 0.8541 - val_loss: 0.4088
# Epoch 6/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8290 - loss: 0.4507 - val_accuracy: 0.8541 - val_loss: 0.4035
# Epoch 7/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8206 - loss: 0.4730 - val_accuracy: 0.8541 - val_loss: 0.4021
# Epoch 8/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8433 - loss: 0.3892 - val_accuracy: 0.8541 - val_loss: 0.3632
# Epoch 115/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8185 - loss: 0.4098 - val_accuracy: 0.8541 - val_loss: 0.3627
# Epoch 116/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8063 - loss: 0.4121 - val_accuracy: 0.8541 - val_loss: 0.3630
# Epoch 117/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8147 - loss: 0.3958 - val_accuracy: 0.8541 - val_loss: 0.3627
# Epoch 118/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8062 - loss: 0.4304 - val_accuracy: 0.8541 - val_loss: 0.3628
# Model lstm training complete for niche 5.
#   Final training loss: 0.39921024441719055
#   Final validation loss: 0.3627968728542328
#   Final training accuracy: 0.823655903339386
#   Final validation accuracy: 0.8540772795677185
# Training model cnn for niche 5...
# Epoch 1/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5548 - loss: 0.7032 - val_accuracy: 0.8412 - val_loss: 0.5930
# Epoch 2/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7534 - loss: 0.5900 - val_accuracy: 0.8541 - val_loss: 0.5062
# Epoch 3/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8071 - loss: 0.5314 - val_accuracy: 0.8541 - val_loss: 0.4548
# Epoch 4/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8162 - loss: 0.4899 - val_accuracy: 0.8541 - val_loss: 0.4266
# Epoch 5/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8260 - loss: 0.4599 - val_accuracy: 0.8541 - val_loss: 0.4123
# Epoch 6/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8422 - loss: 0.4293 - val_accuracy: 0.8541 - val_loss: 0.4048
# Epoch 7/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8200 - loss: 0.4428 - val_accuracy: 0.8541 - val_loss: 0.3987
# Epoch 8/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8174 - loss: 0.4477 - val_accuracy: 0.8541 - val_loss: 0.3933
# Epoch 9/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8421 - loss: 0.4167 - val_accuracy: 0.8541 - val_loss: 0.3892
# Epoch 10/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8343 - loss: 0.4060 - val_accuracy: 0.8541 - val_loss: 0.3857
# Epoch 11/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8142 - loss: 0.4490 - val_accuracy: 0.8541 - val_loss: 0.3834
# Epoch 12/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8342 - loss: 0.4102 - val_accuracy: 0.8541 - val_loss: 0.3795
# Epoch 13/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8115 - loss: 0.4320 - val_accuracy: 0.8541 - val_loss: 0.3765
# Epoch 14/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8080 - loss: 0.4339 - val_accuracy: 0.8541 - val_loss: 0.3744
# Epoch 15/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8293 - loss: 0.4083 - val_accuracy: 0.8541 - val_loss: 0.3730
# Epoch 16/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8140 - loss: 0.4133 - val_accuracy: 0.8541 - val_loss: 0.3715
# Epoch 17/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8447 - loss: 0.3978 - val_accuracy: 0.8541 - val_loss: 0.3700
# Epoch 18/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8093 - loss: 0.4331 - val_accuracy: 0.8541 - val_loss: 0.3689
# Epoch 19/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8218 - loss: 0.4128 - val_accuracy: 0.8541 - val_loss: 0.3669
# Epoch 20/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8007 - loss: 0.4316 - val_accuracy: 0.8541 - val_loss: 0.3657
# Epoch 21/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8207 - loss: 0.4114 - val_accuracy: 0.8541 - val_loss: 0.3644
# Epoch 22/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8244 - loss: 0.3925 - val_accuracy: 0.8541 - val_loss: 0.3640
# Epoch 23/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4335 - val_accuracy: 0.8541 - val_loss: 0.3627
# Epoch 24/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8282 - loss: 0.3890 - val_accuracy: 0.8541 - val_loss: 0.3625
# Epoch 25/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8025 - loss: 0.4371 - val_accuracy: 0.8541 - val_loss: 0.3622
# Epoch 26/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8319 - loss: 0.3907 - val_accuracy: 0.8541 - val_loss: 0.3611
# Epoch 27/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8321 - loss: 0.4002 - val_accuracy: 0.8541 - val_loss: 0.3609
# Epoch 28/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.4274 - val_accuracy: 0.8541 - val_loss: 0.3605
# Epoch 29/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7904 - loss: 0.4370 - val_accuracy: 0.8541 - val_loss: 0.3604
# Epoch 30/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8143 - loss: 0.4104 - val_accuracy: 0.8541 - val_loss: 0.3598
# Epoch 31/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8158 - loss: 0.3999 - val_accuracy: 0.8541 - val_loss: 0.3589
# Epoch 32/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8331 - loss: 0.3791 - val_accuracy: 0.8541 - val_loss: 0.3589
# Epoch 33/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8317 - loss: 0.3920 - val_accuracy: 0.8541 - val_loss: 0.3592
# Epoch 34/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8338 - loss: 0.3731 - val_accuracy: 0.8541 - val_loss: 0.3589
# Epoch 35/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8323 - loss: 0.3918 - val_accuracy: 0.8541 - val_loss: 0.3586
# Epoch 36/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8221 - loss: 0.3938 - val_accuracy: 0.8541 - val_loss: 0.3591
# Epoch 37/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8471 - loss: 0.3858 - val_accuracy: 0.8541 - val_loss: 0.3589
# Epoch 38/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7922 - loss: 0.4197 - val_accuracy: 0.8541 - val_loss: 0.3593
# Epoch 39/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8203 - loss: 0.3975 - val_accuracy: 0.8541 - val_loss: 0.3585
# Epoch 40/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8335 - loss: 0.3736 - val_accuracy: 0.8541 - val_loss: 0.3587
# Epoch 41/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8287 - loss: 0.3822 - val_accuracy: 0.8541 - val_loss: 0.3586
# Epoch 42/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8286 - loss: 0.3938 - val_accuracy: 0.8541 - val_loss: 0.3585
# Epoch 43/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8335 - loss: 0.3799 - val_accuracy: 0.8541 - val_loss: 0.3583
# Epoch 44/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8274 - loss: 0.3742 - val_accuracy: 0.8541 - val_loss: 0.3583
# Epoch 45/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8061 - loss: 0.4199 - val_accuracy: 0.8541 - val_loss: 0.3580
# Epoch 46/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8367 - loss: 0.3711 - val_accuracy: 0.8541 - val_loss: 0.3581
# Epoch 47/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8332 - loss: 0.3949 - val_accuracy: 0.8541 - val_loss: 0.3575
# Epoch 48/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8101 - loss: 0.3921 - val_accuracy: 0.8541 - val_loss: 0.3576
# Epoch 49/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8238 - loss: 0.3548 - val_accuracy: 0.8541 - val_loss: 0.3580
# Epoch 50/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8120 - loss: 0.4155 - val_accuracy: 0.8541 - val_loss: 0.3575
# Epoch 51/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8400 - loss: 0.3910 - val_accuracy: 0.8541 - val_loss: 0.3574
# Epoch 52/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8437 - loss: 0.3652 - val_accuracy: 0.8541 - val_loss: 0.3574
# Epoch 53/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8282 - loss: 0.3764 - val_accuracy: 0.8541 - val_loss: 0.3577
# Epoch 54/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8056 - loss: 0.4172 - val_accuracy: 0.8541 - val_loss: 0.3576
# Epoch 55/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8213 - loss: 0.3946 - val_accuracy: 0.8541 - val_loss: 0.3572
# Epoch 56/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8236 - loss: 0.3850 - val_accuracy: 0.8541 - val_loss: 0.3575
# Epoch 57/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8326 - loss: 0.3831 - val_accuracy: 0.8541 - val_loss: 0.3575
# ...
# Epoch 40/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9443 - loss: 0.2563 - val_accuracy: 0.9375 - val_loss: 0.2488
# Epoch 41/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9525 - loss: 0.2220 - val_accuracy: 0.9375 - val_loss: 0.2494
# Epoch 42/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9348 - loss: 0.2406 - val_accuracy: 0.9375 - val_loss: 0.2491
# Epoch 43/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.2050 - val_accuracy: 0.9375 - val_loss: 0.2493
# Epoch 44/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9491 - loss: 0.2214 - val_accuracy: 0.9375 - val_loss: 0.2494
# Epoch 45/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9484 - loss: 0.2564 - val_accuracy: 0.9375 - val_loss: 0.2495
# Epoch 46/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.2340 - val_accuracy: 0.9375 - val_loss: 0.2497
# Epoch 47/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9380 - loss: 0.2310 - val_accuracy: 0.9375 - val_loss: 0.2499
# Model mlp_market training complete for niche 4.
#   Final training loss: 0.2375740259885788
#   Final validation loss: 0.24987922608852386
#   Final training accuracy: 0.9409449100494385
#   Final validation accuracy: 0.9375
# Training model lstm for niche 4...
# Epoch 1/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2420 - loss: 0.7601 - val_accuracy: 0.2031 - val_loss: 0.7117
# Epoch 2/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5101 - loss: 0.7015 - val_accuracy: 0.9219 - val_loss: 0.6599
# Epoch 3/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7431 - loss: 0.6504 - val_accuracy: 0.9375 - val_loss: 0.6101
# Epoch 4/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8435 - loss: 0.5994 - val_accuracy: 0.9375 - val_loss: 0.5483
# Epoch 5/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9045 - loss: 0.5341 - val_accuracy: 0.9375 - val_loss: 0.4591
# Epoch 6/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9309 - loss: 0.4514 - val_accuracy: 0.9375 - val_loss: 0.3076
# Epoch 7/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9318 - loss: 0.3208 - val_accuracy: 0.9375 - val_loss: 0.2173
# Epoch 8/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9410 - loss: 0.2954 - val_accuracy: 0.9375 - val_loss: 0.2180
# Epoch 9/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9378 - loss: 0.2696 - val_accuracy: 0.9375 - val_loss: 0.2177
# Epoch 10/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.2322 - val_accuracy: 0.9375 - val_loss: 0.2204
# Epoch 11/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9276 - loss: 0.2809 - val_accuracy: 0.9375 - val_loss: 0.2184
# Epoch 12/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9350 - loss: 0.3109 - val_accuracy: 0.9375 - val_loss: 0.2185
# Epoch 13/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9426 - loss: 0.2644 - val_accuracy: 0.9375 - val_loss: 0.2191
# Epoch 14/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9363 - loss: 0.2702 - val_accuracy: 0.9375 - val_loss: 0.2199
# Epoch 15/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9287 - loss: 0.2582 - val_accuracy: 0.9375 - val_loss: 0.2229
# Epoch 16/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9503 - loss: 0.2373 - val_accuracy: 0.9375 - val_loss: 0.2254
# Epoch 17/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9477 - loss: 0.2235 - val_accuracy: 0.9375 - val_loss: 0.2207
# Model lstm training complete for niche 4.
#   Final training loss: 0.23828621208667755
#   Final validation loss: 0.22071988880634308
#   Final training accuracy: 0.9409449100494385
#   Final validation accuracy: 0.9375
# Training model cnn for niche 4...
# Epoch 1/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6980 - loss: 0.6068 - val_accuracy: 0.8984 - val_loss: 0.5041
# Epoch 2/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8214 - loss: 0.5153 - val_accuracy: 0.9297 - val_loss: 0.4265
# Epoch 3/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8957 - loss: 0.4434 - val_accuracy: 0.9375 - val_loss: 0.3620
# Epoch 4/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9383 - loss: 0.3778 - val_accuracy: 0.9375 - val_loss: 0.3114
# Epoch 5/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9489 - loss: 0.3048 - val_accuracy: 0.9375 - val_loss: 0.2750
# Epoch 6/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9476 - loss: 0.2709 - val_accuracy: 0.9375 - val_loss: 0.2493
# Epoch 7/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9391 - loss: 0.2878 - val_accuracy: 0.9375 - val_loss: 0.2352
# Epoch 8/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9505 - loss: 0.2292 - val_accuracy: 0.9375 - val_loss: 0.2264
# Epoch 9/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9448 - loss: 0.2417 - val_accuracy: 0.9375 - val_loss: 0.2224
# Epoch 10/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9322 - loss: 0.2771 - val_accuracy: 0.9375 - val_loss: 0.2205
# Epoch 11/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9559 - loss: 0.2001 - val_accuracy: 0.9375 - val_loss: 0.2190
# Epoch 12/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9302 - loss: 0.2601 - val_accuracy: 0.9375 - val_loss: 0.2184
# Epoch 13/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9339 - loss: 0.2600 - val_accuracy: 0.9375 - val_loss: 0.2182
# Epoch 14/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9369 - loss: 0.2280 - val_accuracy: 0.9375 - val_loss: 0.2182
# Epoch 15/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9497 - loss: 0.2032 - val_accuracy: 0.9375 - val_loss: 0.2179
# Epoch 16/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9415 - loss: 0.2258 - val_accuracy: 0.9375 - val_loss: 0.2173
# Epoch 17/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9440 - loss: 0.2071 - val_accuracy: 0.9375 - val_loss: 0.2168
# Epoch 18/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9332 - loss: 0.2357 - val_accuracy: 0.9375 - val_loss: 0.2165
# Epoch 19/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9144 - loss: 0.2854 - val_accuracy: 0.9375 - val_loss: 0.2164
# Epoch 20/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9398 - loss: 0.2220 - val_accuracy: 0.9375 - val_loss: 0.2163
# Epoch 21/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9306 - loss: 0.2560 - val_accuracy: 0.9375 - val_loss: 0.2161
# Epoch 22/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9442 - loss: 0.2032 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 23/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9457 - loss: 0.2155 - val_accuracy: 0.9375 - val_loss: 0.2158
# Epoch 24/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9440 - loss: 0.2068 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 25/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9454 - loss: 0.2205 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 26/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.2505 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 27/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.2193 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 28/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9354 - loss: 0.2166 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 29/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9419 - loss: 0.1954 - val_accuracy: 0.9375 - val_loss: 0.2160
# Epoch 30/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9504 - loss: 0.1904 - val_accuracy: 0.9375 - val_loss: 0.2162
# Epoch 31/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9456 - loss: 0.1930 - val_accuracy: 0.9375 - val_loss: 0.2163
# Epoch 32/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9427 - loss: 0.1934 - val_accuracy: 0.9375 - val_loss: 0.2163
# Epoch 33/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.2389 - val_accuracy: 0.9375 - val_loss: 0.2162
# Model cnn training complete for niche 4.
#   Final training loss: 0.21420294046401978
#   Final validation loss: 0.21621322631835938
#   Final training accuracy: 0.9409449100494385
#   Final validation accuracy: 0.9375
# Training model random_forest for niche 4...
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Performance for niche 5:
#   mlp_financial: Loss = 0.39850395917892456, Accuracy = 0.8336673378944397
#   mlp_market: Loss = 0.39497047662734985, Accuracy = 0.8336673378944397
#   lstm: Loss = 0.38005658984184265, Accuracy = 0.8336673378944397
#   cnn: Loss = 0.3774825930595398, Accuracy = 0.8336673378944397
#   random_forest: Loss = 0.9972323522438671, Accuracy = 0.811623246492986
# Performance for niche 9:
#   mlp_financial: Loss = 0.22482499480247498, Accuracy = 0.936898410320282
#   mlp_market: Loss = 0.22250530123710632, Accuracy = 0.936898410320282
#   lstm: Loss = 0.21920959651470184, Accuracy = 0.936898410320282
#   cnn: Loss = 0.2192772626876831, Accuracy = 0.936898410320282
#   random_forest: Loss = 0.5052295267083335, Accuracy = 0.9251336898395722
# Performance for niche 3:
#   mlp_financial: Loss = 0.19625836610794067, Accuracy = 0.9527027010917664
#   mlp_market: Loss = 0.19972948729991913, Accuracy = 0.9527027010917664
#   lstm: Loss = 0.19154340028762817, Accuracy = 0.9527027010917664
#   cnn: Loss = 0.18602439761161804, Accuracy = 0.9527027010917664
#   random_forest: Loss = 0.7280199051687616, Accuracy = 0.9527027027027027
# Performance for niche 1:
#   mlp_financial: Loss = 0.12790614366531372, Accuracy = 0.977886974811554
#   mlp_market: Loss = 0.14621469378471375, Accuracy = 0.977886974811554
#   lstm: Loss = 0.1066175252199173, Accuracy = 0.977886974811554
#   cnn: Loss = 0.10812173038721085, Accuracy = 0.977886974811554
#   random_forest: Loss = 0.5944440667749943, Accuracy = 0.9680589680589681
# Performance for niche 8:
#   mlp_financial: Loss = 0.32587727904319763, Accuracy = 0.9021164178848267
#   mlp_market: Loss = 0.3240807056427002, Accuracy = 0.9021164178848267
#   lstm: Loss = 0.30766892433166504, Accuracy = 0.9021164178848267
#   cnn: Loss = 0.29849088191986084, Accuracy = 0.9021164178848267
#   random_forest: Loss = 0.44845698302350484, Accuracy = 0.9021164021164021
# Performance for niche 6:
#   mlp_financial: Loss = 0.29155078530311584, Accuracy = 0.9146141409873962
#   mlp_market: Loss = 0.29647544026374817, Accuracy = 0.9146141409873962
#   lstm: Loss = 0.26963281631469727, Accuracy = 0.9146141409873962
#   cnn: Loss = 0.2645053565502167, Accuracy = 0.9146141409873962
#   random_forest: Loss = 0.7490301042782366, Accuracy = 0.9080459770114943
# Performance for niche 2:
#   mlp_financial: Loss = 0.19261133670806885, Accuracy = 0.9537953734397888
#   mlp_market: Loss = 0.18410073220729828, Accuracy = 0.9537953734397888
#   lstm: Loss = 0.17600733041763306, Accuracy = 0.9537953734397888
#   cnn: Loss = 0.18634100258350372, Accuracy = 0.9537953734397888
#   random_forest: Loss = 0.48055483128730664, Accuracy = 0.9372937293729373
# Performance for niche 0:
#   mlp_financial: Loss = 0.2560548186302185, Accuracy = 0.9237288236618042
#   mlp_market: Loss = 0.25373321771621704, Accuracy = 0.9237288236618042
#   lstm: Loss = 0.24568018317222595, Accuracy = 0.9237288236618042
#   cnn: Loss = 0.24885787069797516, Accuracy = 0.9237288236618042
#   random_forest: Loss = 0.7150441689029653, Accuracy = 0.911864406779661
# Performance for niche 7:
#   mlp_financial: Loss = 0.2264016717672348, Accuracy = 0.944615364074707
#   mlp_market: Loss = 0.2429068684577942, Accuracy = 0.944615364074707
#   lstm: Loss = 0.2200850248336792, Accuracy = 0.944615364074707
#   cnn: Loss = 0.21230722963809967, Accuracy = 0.944615364074707
#   random_forest: Loss = 0.8046323323421821, Accuracy = 0.9415384615384615
# Performance for niche 4:
#   mlp_financial: Loss = 0.33967888355255127, Accuracy = 0.9084249138832092
#   mlp_market: Loss = 0.351594477891922, Accuracy = 0.9084249138832092
#   lstm: Loss = 0.4422498345375061, Accuracy = 0.9084249138832092
#   cnn: Loss = 0.2974397838115692, Accuracy = 0.9084249138832092
#   random_forest: Loss = 0.9934155787348361, Accuracy = 0.9084249084249084
# Best performing model for niche 5: cnn with performance: [0.3774825930595398, 0.8336673378944397]
# Best performing model for niche 9: lstm with performance: [0.21920959651470184, 0.936898410320282]
# Best performing model for niche 3: cnn with performance: [0.18602439761161804, 0.9527027010917664]
# Best performing model for niche 1: lstm with performance: [0.1066175252199173, 0.977886974811554]
# Best performing model for niche 8: cnn with performance: [0.29849088191986084, 0.9021164178848267]
# Best performing model for niche 6: cnn with performance: [0.2645053565502167, 0.9146141409873962]
# Best performing model for niche 2: lstm with performance: [0.17600733041763306, 0.9537953734397888]
# Best performing model for niche 0: lstm with performance: [0.24568018317222595, 0.9237288236618042]
# Best performing model for niche 7: cnn with performance: [0.21230722963809967, 0.944615364074707]
# Best performing model for niche 4: cnn with performance: [0.2974397838115692, 0.9084249138832092]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# Load dataset
df = pd.read_csv('./dataset_transformed.csv')

# Drop rows with missing values in critical columns
df.dropna(subset=['status', 'funding_total_usd', 'country_code'], inplace=True)

# Encode categorical columns
label_encoders = {}
for column in ['category_list', 'country_code', 'state_code', 'region', 'city', 'first_funding_at', 'last_funding_at', 'founded_at']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le

# Convert 'status' to binary classification (1 for operating, 0 for closed)
df['status'] = df['status'].apply(lambda x: 0 if x == 'closed' else 1)

# Handle 'funding_total_usd' column (convert '-' to 0 and convert to float)
df['funding_total_usd'] = df['funding_total_usd'].replace('-', 0).astype(float)

# Features and target
X = df.drop(columns=['status'])
y = df['status']

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

joblib.dump(scaler, 'scaler.pkl')
joblib.dump(label_encoders, 'label_encoders.pkl')

# Define the MLP model
def build_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(20, activation='relu', input_dim=input_dim , kernel_regularizer=regularizers.l2(l2_penalty)))
    model.add(Dropout(0.5))
    model.add(Dense(25, activation='relu' , kernel_regularizer=regularizers.l2(l2_penalty)))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Split the data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Build and train the MLP model
mlp_model = build_mlp_model(X_train.shape[1])

# Define callbacks for early stopping and model checkpointing
checkpoint_path = "./mlp_model_checkpoint.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = mlp_model.fit(X_train, y_train, epochs=epoch, batch_size=32, validation_split=0.2, verbose=1, callbacks=[checkpoint, early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = mlp_model.evaluate(X_test, y_test, verbose=0)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Save the final model
mlp_model.save('mlp_model.h5')

print("MLP model training complete and saved.")
# Out:
# Epoch 1/1000
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8724 - loss: 0.4344 - val_accuracy: 0.9189 - val_loss: 0.2959
# Epoch 2/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9256 - loss: 0.3079 - val_accuracy: 0.9189 - val_loss: 0.2849
# Epoch 3/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9256 - loss: 0.2949 - val_accuracy: 0.9189 - val_loss: 0.2800
# Epoch 4/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9258 - loss: 0.2854 - val_accuracy: 0.9189 - val_loss: 0.2765
# Epoch 5/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9278 - loss: 0.2746 - val_accuracy: 0.9189 - val_loss: 0.2730
# Epoch 6/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9289 - loss: 0.2668 - val_accuracy: 0.9189 - val_loss: 0.2706
# Epoch 7/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9270 - loss: 0.2623 - val_accuracy: 0.9189 - val_loss: 0.2688
# Epoch 8/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9248 - loss: 0.2679 - val_accuracy: 0.9189 - val_loss: 0.2672
# Epoch 9/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9238 - loss: 0.2680 - val_accuracy: 0.9189 - val_loss: 0.2660
# Epoch 10/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9274 - loss: 0.2504 - val_accuracy: 0.9189 - val_loss: 0.2644
# Epoch 11/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9269 - loss: 0.2556 - val_accuracy: 0.9189 - val_loss: 0.2633
# Epoch 12/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9271 - loss: 0.2485 - val_accuracy: 0.9189 - val_loss: 0.2629
# Epoch 13/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9211 - loss: 0.2639 - val_accuracy: 0.9189 - val_loss: 0.2623
# Epoch 14/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9199 - loss: 0.2624 - val_accuracy: 0.9189 - val_loss: 0.2611
# Epoch 15/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9222 - loss: 0.2571 - val_accuracy: 0.9189 - val_loss: 0.2601
# Epoch 16/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9230 - loss: 0.2520 - val_accuracy: 0.9189 - val_loss: 0.2596
# Epoch 17/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2656 - val_accuracy: 0.9189 - val_loss: 0.2594
# Epoch 18/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9237 - loss: 0.2500 - val_accuracy: 0.9189 - val_loss: 0.2579
# Epoch 19/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9248 - loss: 0.2489 - val_accuracy: 0.9189 - val_loss: 0.2576
# Epoch 20/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2548 - val_accuracy: 0.9189 - val_loss: 0.2571
# Epoch 21/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9243 - loss: 0.2515 - val_accuracy: 0.9189 - val_loss: 0.2577
# Epoch 22/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9240 - loss: 0.2467 - val_accuracy: 0.9189 - val_loss: 0.2585
# Epoch 23/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9289 - loss: 0.2421 - val_accuracy: 0.9189 - val_loss: 0.2565
# Epoch 24/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9248 - loss: 0.2513 - val_accuracy: 0.9189 - val_loss: 0.2587
# Epoch 25/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9268 - loss: 0.2413 - val_accuracy: 0.9189 - val_loss: 0.2562
# Epoch 26/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9300 - loss: 0.2342 - val_accuracy: 0.9189 - val_loss: 0.2570
# Epoch 27/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9250 - loss: 0.2492 - val_accuracy: 0.9189 - val_loss: 0.2571
# Epoch 28/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9260 - loss: 0.2459 - val_accuracy: 0.9189 - val_loss: 0.2564
# Epoch 29/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9262 - loss: 0.2414 - val_accuracy: 0.9189 - val_loss: 0.2569
# Epoch 30/1000
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9239 - loss: 0.2451 - val_accuracy: 0.9189 - val_loss: 0.2578
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Loss: 0.23735898733139038
# Test Accuracy: 0.9277201294898987
# MLP model training complete and saved.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os
import joblib


df = pd.read_csv("./dataset_transformed.csv")


# df_software = df[df['category_list'] == label_encoders['category_list'].transform(['Apps'])[0]]

# Split the "Software" category data into training and test sets
df_train_software, df_test_software = train_test_split(df, test_size=0.7, random_state=56)

# Save the test dataset to a CSV file
test_software_file_path = './test_dataset.csv'
df_test_software.to_csv(test_software_file_path, index=False)

# %%
print("Evaluating :")
# Load the models
model_1 = tf.keras.models.load_model('./mlp_model.h5')
model_2 = tf.keras.models.load_model('./best_model_1.h5')

# Load label encoders and scaler
label_encoders = joblib.load('./label_encoders.pkl')
scaler = joblib.load('./scaler.pkl')

# Load test dataset
df_test = pd.read_csv('./test_dataset.csv')

# Drop rows with missing values in critical columns
df_test.dropna(subset=['status', 'funding_total_usd', 'country_code'], inplace=True)

# Encode categorical columns using the existing label encoders
for column in ['category_list', 'country_code', 'state_code', 'region', 'city', 'first_funding_at', 'last_funding_at', 'founded_at']:
    le = label_encoders[column]
    df_test[column] = df_test[column].astype(str)
    df_test[column] = df_test[column].apply(lambda x: le.transform([x])[0] if x in le.classes_ else -1)

# Convert 'status' to binary classification (1 for operating, 0 for closed)
df_test['status'] = df_test['status'].apply(lambda x: 0 if x == 'closed' else 1)

# Handle 'funding_total_usd' column (convert '-' to 0 and convert to float)
df_test['funding_total_usd'] = df_test['funding_total_usd'].replace('-', 0).astype(float)

# Features and target
X_test = df_test.drop(columns=['status'])
y_test = df_test['status']

# Standardize the features
X_test = scaler.transform(X_test)

# Evaluate model_1
loss_1, accuracy_1 = model_1.evaluate(X_test, y_test, verbose=0)
print(f"General - Test Loss: {loss_1}, Test Accuracy: {accuracy_1}")

# Evaluate model_2
loss_2, accuracy_2 = model_2.evaluate(X_test, y_test, verbose=0)
print(f"Specialized - Test Loss: {loss_2}, Test Accuracy: {accuracy_2}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Evaluating :
# General - Test Loss: 0.24369636178016663, Test Accuracy: 0.9240339398384094
# Specialized - Test Loss: 0.26028895378112793, Test Accuracy: 0.9240339398384094

# %%
# #Visulaizing the model 
# import visualkeras
# model_1 = tf.keras.models.load_model('./mlp_model.h5')
# model_2 = tf.keras.models.load_model('./best_model_0.h5')
# visualkeras.layered_view(model_2, type_ignore=[ Dropout])
# visualkeras.layered_view(model_2, to_file='model_specilized.png') # write to disk
# visualkeras.layered_view(model_2, to_file='model_specilized.png').show() # write and show

# %%
# Evaluate model_1
loss_1, accuracy_1 = model_1.evaluate(X_test, y_test, verbose=0)
print(f"General - Test Loss: {loss_1}, Test Accuracy: {accuracy_1}")

# Evaluate model_2
loss_2, accuracy_2 = model_2.evaluate(X_test, y_test, verbose=0)
print(f"Specialized - Test Loss: {loss_2}, Test Accuracy: {accuracy_2}")

from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

# Make predictions
y_pred_1 = (model_1.predict(X_test) > 0.5).astype("int32")
y_pred_2 = (model_2.predict(X_test) > 0.5).astype("int32")

print("Model 1 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_1))
print("Model 1 Classification Report:")
print(classification_report(y_test, y_pred_1))
print("Model 1 Precision:", precision_score(y_test, y_pred_1))
print("Model 1 Recall:", recall_score(y_test, y_pred_1))
print("Model 1 F1 Score:", f1_score(y_test, y_pred_1))

# Confusion Matrix and Classification Report for Model 2
print("Model 2 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_2))
print("Model 2 Classification Report:")
print(classification_report(y_test, y_pred_2))
print("Model 2 Precision:", precision_score(y_test, y_pred_2))
print("Model 2 Recall:", recall_score(y_test, y_pred_2))
print("Model 2 F1 Score:", f1_score(y_test, y_pred_2))
# Out:
# General - Test Loss: 0.248529314994812, Test Accuracy: 0.9225298166275024
# Specialized - Test Loss: 0.5699695944786072, Test Accuracy: 0.9225298166275024
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Model 1 Confusion Matrix:
# [[   0  403]
#  [   0 4799]]
# Model 1 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       403
#            1       0.92      1.00      0.96      4799
#
#     accuracy                           0.92      5202
#    macro avg       0.46      0.50      0.48      5202
# weighted avg       0.85      0.92      0.89      5202
#
# Model 1 Precision: 0.9225297962322184
# Model 1 Recall: 1.0
# Model 1 F1 Score: 0.9597040295970403
# Model 2 Confusion Matrix:
# [[   0  403]
#  [   0 4799]]
# Model 2 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       403
#            1       0.92      1.00      0.96      4799
#
#     accuracy                           0.92      5202
#    macro avg       0.46      0.50      0.48      5202
# weighted avg       0.85      0.92      0.89      5202
#
# Model 2 Precision: 0.9225297962322184
# Model 2 Recall: 1.0
# Model 2 F1 Score: 0.9597040295970403
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\affan\Needfit Agency\LeapstartAi\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
